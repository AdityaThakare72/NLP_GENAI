# %%
import torch

# %%
torch.__version__
# Out:
# '2.5.1+cu124'

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# !nvdia-smi
# Out:
# /bin/bash: line 1: nvdia-smi: command not found

# %%
a = torch.empty(3,4)

# %%
a
# Out:
# tensor([[4.8899e-04, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [       nan, 0.0000e+00, 1.7753e+28, 7.1493e+22],
#         [1.1989e+33, 7.0355e+22, 3.9615e+28, 3.8016e-39]])

# %%
type(a)
# Out:
# torch.Tensor

# %%
a.fill_(10)
# Out:
# tensor([[10., 10., 10., 10.],
#         [10., 10., 10., 10.],
#         [10., 10., 10., 10.]])

# %%
torch.zeros(3,2)
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
torch.rand(3,4)
# Out:
# tensor([[0.0027, 0.9202, 0.7786, 0.2738],
#         [0.7294, 0.8581, 0.3297, 0.4035],
#         [0.4752, 0.1468, 0.1318, 0.4383]])

# %%
torch.randn(2,3)
# Out:
# tensor([[ 0.4197,  0.1960,  1.1110],
#         [ 0.0412, -0.5837,  0.5882]])

# %%
# fixing the random seed

torch.manual_seed(0)
torch.rand(2,3)
# Out:
# tensor([[0.4963, 0.7682, 0.0885],
#         [0.1320, 0.3074, 0.6341]])

# %%
# custom tensor
torch.tensor([[2,3,4], [1,2,3]])
# Out:
# tensor([[2, 3, 4],
#         [1, 2, 3]])

# %%
torch.arange(2,10,1)
# Out:
# tensor([2, 3, 4, 5, 6, 7, 8, 9])

# %%
# generate 10 numbers between 1 to 5
torch.linspace(1, 5, 20)
# Out:
# tensor([1.0000, 1.2105, 1.4211, 1.6316, 1.8421, 2.0526, 2.2632, 2.4737, 2.6842,
#         2.8947, 3.1053, 3.3158, 3.5263, 3.7368, 3.9474, 4.1579, 4.3684, 4.5789,
#         4.7895, 5.0000])

# %%
# identical matrix
torch.eye(3)
# Out:
# tensor([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])

# %%
# matrix containing a specific value
torch.full((2,3), 5)
# Out:
# tensor([[5, 5, 5],
#         [5, 5, 5]])

# %%
a = torch.tensor([[1,2,3], [4,5,6]])
a
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
a.shape
# Out:
# torch.Size([2, 3])

# %%
# empty like
torch.empty_like(a)
# Out:
# tensor([[7310224141727195513, 2322206415573840755, 7377567313477908002],
#         [3473174048420277554, 3630855912818894182, 7220454605962229303]])

# %%
torch.zeros_like(a)
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]])

# %%
torch.rand_like(a, dtype= torch.float32)
# Out:
# tensor([[0.4901, 0.8964, 0.4556],
#         [0.6323, 0.3489, 0.4017]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
a + 2    # performs like arrays
# Out:
# tensor([[3, 4, 5],
#         [6, 7, 8]])

# %%
torch.neg(a)
# Out:
# tensor([[-1, -2, -3],
#         [-4, -5, -6]])

# %%
x = torch.tensor([1.2, 3.4, 5.2, 8.9])

# %%
torch.round(x)
# Out:
# tensor([1., 3., 5., 9.])

# %%
torch.floor(x)
# Out:
# tensor([1., 3., 5., 8.])

# %%
torch.ceil(x)
# Out:
# tensor([2., 4., 6., 9.])

# %%
e = torch.randint(size = (3,4), low = 12, high = 20)
e
# Out:
# tensor([[12, 13, 17, 13],
#         [17, 12, 13, 16],
#         [15, 12, 15, 17]])

# %%
torch.sum(e)
# Out:
# tensor(172)

# %%
torch.sum(e, dim =0)
# Out:
# tensor([44, 37, 45, 46])

# %%
torch.sum(e, dim =1)
# Out:
# tensor([55, 58, 59])

# %%
torch.mean(e, dim = 1)
# only if float values
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 torch.mean(e, dim = 1)
#       2 # only if float values
#
# RuntimeError: mean(): could not infer output dtype. Input dtype must be either a floating point or complex dtype. Got: Long

# %%
torch.argmax(e) # index of highest value

# also index here will be the linear one unlike index of row and col
# Out:
# tensor(2)

# %%
torch.argmin(e)
# Out:
# tensor(0)

# %%
e[torch.argmax(e)]
# Out:
# tensor([15, 12, 15, 17])

# %%
 # tensor/matrix operations

# %%
o = torch.randint(size=(2,3), low = 0, high= 5)
p = torch.randint(size=(3,2), low = 2, high = 10)

# %%
o,p
# Out:
# (tensor([[2, 4, 1],
#          [3, 3, 3]]),
#  tensor([[2, 3],
#          [5, 7],
#          [5, 5]]))

# %%
# matrix mult
torch.matmul(o,p)
# 2x3  *   3x2  => 2x2
# no of cols = no of rows
# Out:
# tensor([[29, 39],
#         [36, 45]])

# %%
# dot product of vectors

# %%
vec1 = torch.tensor([1, 3])
vec2 = torch.tensor([3, 4])

# %%
torch.dot(vec1, vec2)
# Out:
# tensor(15)

# %%
o
# Out:
# tensor([[2, 4, 1],
#         [3, 3, 3]])

# %%
torch.transpose(o, 0, 1)
# Out:
# tensor([[2, 3],
#         [4, 3],
#         [1, 3]])

# %%
torch.log(o)
# Out:
# tensor([[0.6931, 1.3863, 0.0000],
#         [1.0986, 1.0986, 1.0986]])

# %%
torch.exp(o)
# Out:
# tensor([[ 7.3891, 54.5981,  2.7183],
#         [20.0855, 20.0855, 20.0855]])

# %%
torch.softmax(p, 1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 torch.softmax(p, 1)
#
# RuntimeError: "softmax_lastdim_kernel_impl" not implemented for 'Long'

# %%
# need to convert to float

p = p.float()

# %%
torch.softmax(p, 0)

# 0 or 1 => applied normalization col or row wise
# Out:
# tensor([[0.0243, 0.0159],
#         [0.4879, 0.8668],
#         [0.4879, 0.1173]])
